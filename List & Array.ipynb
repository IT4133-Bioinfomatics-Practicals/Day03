# %%
list = ['apple', 'banana', 'cherry']
# thislist = list(('apple', 'banana', 'cherry'))

print(list)
# Out:
# ['apple', 'banana', 'cherry']

# %%
list = ['ball', 1, 2.45]
print(list)
# Out:
# ['ball', 1, 2.45]

# %%
print(len(list))
# Out:
# 3

# %%
print(type(list))
# Out:
# <class 'list'>

# %%
a = [1, 2, 3, 4, 5, 6]
print(a)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
print(a[2])
# Out:
# 3

# %%
print(len(a))
# Out:
# 6

# %%
a.append(7)
print(a)
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
a.pop()
# Out:
# 7

# %%
print(a)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
a.clear()
print(a)
# Out:
# []

# %%
b = [2, 3, 3, 5, 7, 8]
b.copy()
print(b)
# Out:
# [2, 3, 3, 5, 7, 8]

# %%
print(b.count(3))
# Out:
# 2

# %%
a = [1, 2]
b = [4, 6]
a.extend(b)
print(a)
# Out:
# [1, 2, 4, 6]

# %%
print(a.index(4))
# Out:
# 2

# %%
a.insert(2,1)
print(a)
# Out:
# [1, 2, 1, 4, 6]

# %%
a.remove(1)
print(a)
# Out:
# [2, 1, 4, 6]

# %%
a.sort()
print(a)
# Out:
# [1, 2, 4, 6]
